# %%
# Evaluate on test set
# !python ../src/evaluate.py --data_dir ../data/processed --model_path ../models/cattle_breed_model.pt
# Out:
#               precision    recall  f1-score   support
#
#     Ayrshire       0.97      0.83      0.90        47
#        Brown       0.97      0.89      0.93        44
#         Dane       0.80      0.92      0.86        39
#     Friesian       0.91      0.91      0.91        45
#          Gir       0.86      0.84      0.85        58
#       Jersey       0.94      0.99      0.96        82
#      Sahiwal       0.84      0.86      0.85        71
#
#     accuracy                           0.90       386
#    macro avg       0.90      0.89      0.89       386
# weighted avg       0.90      0.90      0.90       386
#
# Figure(640x480)
# C:\Users\KIIT0001\PycharmProjects\cattle_breed_ai\.venv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...
