# %%
# Import the train function from your script
from src.train import train

# Set training parameters
data_dir = "../data/processed"  # same as --data_dir
epochs = 15                     # same as --epochs
batch_size = 16                 # same as --batch_size
lr = 1e-4                        # same as --lr
model_out = "../models/cattle_breed_model.pt"  # optional, can customize

# Call the train function directly
train(data_dir=data_dir, epochs=epochs, batch_size=batch_size, lr=lr, model_out=model_out)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 83
