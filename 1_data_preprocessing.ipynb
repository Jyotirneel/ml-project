# %%
# Preprocess raw data
# !python ../src/prepare_data.py --raw_dir ../data/raw --out_dir ../data/processed --train_frac 0.7 --val_frac 0.15 --test_frac 0.15
# Out:
# train - Ayrshire: 195 images
# val - Ayrshire: 41 images
# test - Ayrshire: 43 images
# train - Brown: 184 images
# val - Brown: 39 images
# test - Brown: 40 images
# train - Dane: 158 images
# val - Dane: 33 images
# test - Dane: 35 images
# train - Friesian: 193 images
# val - Friesian: 41 images
# test - Friesian: 42 images
# train - Gir: 262 images
# val - Gir: 56 images
# test - Gir: 57 images
# train - Jersey: 194 images
# val - Jersey: 41 images
# test - Jersey: 43 images
# train - Sahiwal: 311 images
# val - Sahiwal: 66 images
# test - Sahiwal: 68 images
